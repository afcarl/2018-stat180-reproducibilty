# %%
import skimage.io as sio

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
im = np.mean(sio.imread('/Users/arokem/Downloads/image.jpeg'), -1)

# %%
im.shape
# Out:
# (2448, 3264)

# %%
import skimage.transform as skt

# %%
resamp = skt.downscale_local_mean(im, (3, 3))[16:, 200:1000]

# %%
resamp.shape
# Out:
# (800, 800)

# %%
plt.matshow(resamp)

# %%
from skimage.morphology import disk

# %%
from skimage.filters import rank

# %%
d10 = disk(12)

# %%
d10.shape
# Out:
# (25, 25)
